# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# 모델 Load
model = YOLO("yolov8n.pt")

# 학습
results = model.train(
    data="/content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/personDetection.v1i.yolov8/data.yaml",
    epochs=100,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 400MB/s]
# Ultralytics 8.3.145 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Validation 결과(mAP) 확인
metrics = model.val()
metrics.box.map
metrics.box.map50
metrics.box.map75
metrics.box.maps
# Out:
# Ultralytics 8.3.145 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 25.1±18.4 MB/s, size: 56.3 KB)
# val: Scanning /content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/personDetection.v1i.yolov8/valid/labels.cache... 5 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5/5 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
#                    all          5         13       0.98      0.692      0.708      0.505
# Speed: 0.3ms preprocess, 6.4ms inference, 0.0ms loss, 5.2ms postprocess per image
# Results saved to runs/detect/train3
# array([    0.50476])

# %%
import glob
from PIL import Image

# 테스트 이미지 경로
test_img_folder = "/content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/personDetection.v1i.yolov8/test/images/"
test_imgs = glob.glob(test_img_folder + "*.jpg")

# 결과 저장 폴더
output_folder = "/content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/yolo_test_results/"
import os
os.makedirs(output_folder, exist_ok=True)

# 예측 및 결과 이미지 저장
for img_path in test_imgs:
    results = model(img_path, save=True, project=output_folder)
    # Ultralytics가 자동으로 bounding box 그려서 저장함

print(f"Test 결과 이미지는 {output_folder} 폴더에 저장됩니다.")
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/personDetection.v1i.yolov8/test/images/person15_jpg.rf.bb7145823d0c844a39cf1b02b53e1bd1.jpg: 640x640 3 persons, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/yolo_test_results/train
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/personDetection.v1i.yolov8/test/images/person2_jpg.rf.e8f4c9fbe263968be0ba7fdb692b92e7.jpg: 640x640 6 persons, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/yolo_test_results/train2
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/IntelligenceCapstone/personDetection.v1i.yolov8/test/images/person3_jpg.rf.368aca5d5e6f5741a2f8a75b2c090706.jpg: 640x640 1 person, 7.4ms
# ...
